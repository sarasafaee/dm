# %%
import pandas as pd
import numpy as np
data_digi = pd.read_csv('/content/drive/MyDrive/orders.csv')

# %%
pip install pyfpgrowth

# %%
data_digi.head()
# Out:
#    ID_Order  ID_Customer  ...  city_name_fa Quantity_item
# 0   2714054       469662  ...    محمود آباد           1.0
# 1  11104039      3063877  ...        خرمدره           1.0
# 2   4228130      3184893  ...          قرچک           1.0
# 3  22225624      6888562  ...            قم           1.0
# 4   4068771      2533490  ...         تهران           1.0
#
# [5 rows x 7 columns]

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
grouped = data_digi.groupby(by="ID_Customer")
transactions = []
grouped.filter(lambda x: (transactions.append(x['ID_Item'].to_list()) if x.shape[0] >= 2 else True))
# Out:
#         ID_Order  ID_Customer  ...  city_name_fa Quantity_item
# 1       11104039      3063877  ...        خرمدره           1.0
# 3       22225624      6888562  ...            قم           1.0
# 4        4068771      2533490  ...         تهران           1.0
# 5       11479246      2841640  ...          مشهد           1.0
# 6        8267421      5235886  ...        اصفهان           1.0
# ...          ...          ...  ...           ...           ...
# 199992   7717838      4625961  ...          اراک           5.0
# 199994   4228418      3720408  ...         تهران           1.0
# 199995  12172771      4403268  ...         تهران           2.0
# 199996   4425393      3745774  ...        محمدیه           1.0
# 199997   6671889      4845514  ...        اصفهان           1.0
#
# [122934 rows x 7 columns]

# %%
transactions
# Out:
# [[42545,
#   361304,
#   1523292,
#   1671385,
#   369749,
#   1711488,
#   5265,
#   75068,
#   80046,
#   1771143,
#   81692],
#  [137418, 242763, 295740],
#  [76901, 1390734, 87941],
#  [189732, 4631],
#  [61363, 91566, 20173],
#  [133070, 28236, 114994],
#  [64039, 176246, 1352580, 73772],
#  [116349, 104400],
#  [90646, 9604, 93735, 81785, 183173, 1379404],
#  [32109, 300689, 9780],
#  [34150, 231547],
#  [194997, 90640, 548393],
#  [801172, 608800],
#  [21001, 212460, 272044, 84546, 513728],
#  [178279, 75551, 175451],
#  [422279, 1053717],
#  [222187, 75047, 65304, 124161, 762279],
#  [12129, 32759],
#  [77443, 1085613, 22105],
#  [230221, 217453],
#  [158445, 294942, 1524979],
#  [49386, 45602],
#  [292770, 154714],
#  [1397879, 74926],
#  [66491, 736203],
#  [84376, 110100, 290976],
#  [43533, 567628, 1045534, 373838, 234956, 58753],
#  [19750, 159456],
#  [156293, 8289, 112160, 168431, 564372, 186343, 154714, 417989, 87424],
#  [1483800, 43402],
#  [137583, 115727],
# ...

# %%
pip install fpgrowth_py

# %%
import pyfpgrowth
from fpgrowth_py import fpgrowth
# freqItemSet, rules = fpgrowth(transactions, minSupRatio=0.001, minConf=0.001)

patterns = pyfpgrowth.find_frequent_patterns(transactions, 4)
rules = pyfpgrowth. generate_association_rules(patterns,0.0001)

# %%
rules
# Out:
# {(31619,): ((294942,), 1.0),
#  (94233,): ((), 0.1111111111111111),
#  (104031,): ((388778,), 0.12121212121212122),
#  (294942,): ((31619,), 0.03361344537815126),
#  (388778,): ((104031,), 1.0),
#  (434176,): ((), 0.5),
#  (514658,): ((523762,), 0.15384615384615385),
#  (523762,): ((514658,), 0.2222222222222222)}
